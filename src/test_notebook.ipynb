# %%
import requests
import json
import time

from pymongo import MongoClient
from dotenv import load_dotenv
import os

from bsky_token import load_token
from mongo_connection import connect_to_mongo

# %% [markdown]
# TEST : 05/11/2025

# %%
def search_posts(access_token, query, lang=None, limit=100, cursor=None):
    """
    Recherche des posts publics sur Bluesky selon un mot-clé et une langue.
    """
    url = "https://bsky.social/xrpc/app.bsky.feed.searchPosts"
    headers = {"Authorization": f"Bearer {access_token}"}
    params = {"q": query, "limit": limit}
    if lang:
        params["lang"] = lang
    if cursor:
        params["cursor"] = cursor

    r = requests.get(url, headers=headers, params=params, timeout=10)
    if r.status_code == 200:
        return r.json()
    else:
        print(f"❌ Error search_posts: {r.status_code}: {r.text}")
        return None


def get_author_feed(access_token, handle, limit=100, cursor=None):
    """
    Récupère les posts d’un auteur spécifique (compte d’actualité).
    """
    url = "https://bsky.social/xrpc/app.bsky.feed.getAuthorFeed"
    headers = {"Authorization": f"Bearer {access_token}"}
    params = {"actor": handle, "limit": limit}
    if cursor:
        params["cursor"] = cursor

    r = requests.get(url, headers=headers, params=params, timeout=10)
    if r.status_code == 200:
        return r.json()
    else:
        print(f"❌ Error get_author_feed ({handle}): {r.status_code}: {r.text}")
        return None


def fetch_and_import_to_mongo(access_token, db, collection_name="news_posts", max_posts=500):
    """
    Combine la recherche par mot-clé et la récupération de comptes médias.
    Stocke directement les résultats dans MongoDB.
    """
    topics = ["politics", "government", "election", "policy", "réforme", "war","guerre","politique", "gouvernement", "élection"]
    languages = ["en", "fr"]
    news_accounts = [
        "bbcnews.bsky.social",
        "reuters.com",
        "apnews.com",
        "nytimes.com",
        "washingtonpost.com",
        "lemonde.bsky.social",
        "liberation.bsky.social",
        "afp.com",
        "cnbc.com",
        "usatoday.com",
        "theguardian.com",
        "latimes.com",
        "edition.cnn.com",
        "wsj.com",
        "60minutes.bsky.social",
        "france24.com",
        "bfmtv.com"
    ]

    seen_uris = set()
    collection = db[collection_name]
    collection.create_index("uri", unique=True)


    inserted_count = 0

    # 1️⃣ Recherche par mot-clé
    for lang in languages:
        for topic in topics:
            print(f"\n🔍 Searching for '{topic}' in language '{lang}' …")
            cursor = None
            while inserted_count < max_posts:
                data = search_posts(access_token, query=topic, lang=lang, limit=100, cursor=cursor)
                if not data:
                    break
                posts = data.get("posts", [])
                if not posts:
                    break

                for p in posts:
                    uri = p.get("uri")
                    if uri and not collection.find_one({"uri": uri}):
                        clean_post = {
                                "uri": uri,
                                "author": p.get("author", {}).get("handle"),
                                "text": p.get("record", {}).get("text", ""),
                                "createdAt": p.get("record", {}).get("createdAt", ""),
                                "lang": p.get("record", {}).get("langs", []),
                                "likeCount": p.get("likeCount", 0),
                                "repostCount": p.get("repostCount", 0)
                                }

                        collection.insert_one(clean_post)
                        inserted_count += 1
                        author = p.get("author", {}).get("handle", "unknown")
                        text = p.get("record", {}).get("text", "")
                        print(f"✅ Inserted @{author}: {text[:80]}")

                    if inserted_count >= max_posts:
                        break

                cursor = data.get("cursor")
                if not cursor:
                    break
                time.sleep(1)

    # 2️⃣ Récupération des comptes d’actualité
    for handle in news_accounts:
        print(f"\n📰 Fetching feed from @{handle} …")
        cursor = None
        count_for_author = 0
        while inserted_count < max_posts:
            data = get_author_feed(access_token, handle, limit=100, cursor=cursor)
            if not data:
                break
            feed = data.get("feed", [])
            if not feed:
                break

            for item in feed:
                post = item.get("post", {})
                uri = post.get("uri")
                if uri and not collection.find_one({"uri": uri}):

                    clean_post = {
                        "uri": uri,
                        "author": post.get("author", {}).get("handle", handle),
                        "text": post.get("record", {}).get("text", ""),
                        "createdAt": post.get("record", {}).get("createdAt", ""),
                        "lang": post.get("record", {}).get("langs", []),
                        "likeCount": post.get("likeCount", 0),
                         "repostCount": post.get("repostCount", 0)
                        }
                    
                    collection.insert_one(clean_post)
                    inserted_count += 1
                    count_for_author += 1
                    author = post.get("author", {}).get("handle", handle)
                    text = post.get("record", {}).get("text", "")
                    print(f"🆕 Inserted @{author}: {text[:80]}")

                if inserted_count >= max_posts:
                    break

            cursor = data.get("cursor")
            if not cursor:
                break
            time.sleep(1)
        print(f"✅ {count_for_author} posts collected from @{handle}")

    print(f"\n💾 Total inserted: {inserted_count} posts into '{collection_name}'.")


if __name__ == "__main__":

    token = load_token()
    if token:
        # Connexion MongoDB
        db = connect_to_mongo()
        fetch_and_import_to_mongo(token, db, collection_name="news_posts", max_posts=100)
# Out:
# ✅ Connected to MongoDB Atlas!
# 📂 Database: projet_bluesky
#
# 🔍 Searching for 'politics' in language 'en' …
# ✅ Inserted @froghorde.bsky.social: The “junk food SNAP user” is more myth than fact. It’s a narrative shaped by sti
# ✅ Inserted @michellesea.bsky.social: I have never “done politics” as my friends say
#
# The past 12 months I have been t
# ✅ Inserted @evanminto.com: An acceptance speech referencing Eugene Debs in the first line and focusing expl
# ✅ Inserted @therreport.bsky.social: Don't tell Donald Trump, but Texas is deep into wind and solar power www.motherj
# ✅ Inserted @andyleonard.bsky.social: Politics is not a result of the fall of man into sin. Civil government was creat
# ✅ Inserted @andyleonard.bsky.social: If you're a Christian, our relationship in Christ matters more than politics. If
# ✅ Inserted @prospectmagazine.co.uk: 🎧: On Media Confidential with @arusbridger.bsky.social and @lionelbarber.bsky.so
# ✅ Inserted @bwoar.bsky.social: The Liberals have effed the Reform-Cons. By simply occupying the Brian Mulroney
# ✅ Inserted @hersoldier.bsky.social: Bluepeeps, lets have a
#
# Perverts Out Of Politics March!!!
# ✅ Inserted @criticalthreats.bsky.social: CTP-ISW assessed that some militias, including Badr, may acquiesce to Iranian de
# ✅ Inserted @criticalthreats.bsky.social: MORE | Iran could feasibly use the Badr Organization's influence in the PMF and
# ✅ Inserted @therreport.bsky.social: Zohran Mamdani drags the Democratic Party into the future www.motherjones.com/po
# ✅ Inserted @jaymesdalejr.bsky.social: THIS will be your problem from here on out! Say his name orrealize you will go n
# ✅ Inserted @afriendlybeagle.bsky.social: I love that all my left-wing friends treat /r/conservative like a zoo where all
# ✅ Inserted @mgheinz.bsky.social: Recognize that Dems mostly suck and get out of your team sports mindset about po
# ✅ Inserted @ironeconomist.bsky.social: I think there is also a pretty decent case that if you don’t want to comment you
# ✅ Inserted @gatewaygroupie.com: I'm in such a good mood this morning, Imma email my Ward rep and say hiiiiiii. A
# ✅ Inserted @airbagmoments.bsky.social: Unless Republicans somehow regain sanity, I will never use words like "divide" o
# ✅ Inserted @writertudor.bsky.social: The man whose politics is dreached in nostalgia has lost all hope for a better f
# ✅ Inserted @beneprism.rip: I don't quite get OP. I think Newsom genuinely thinks that "moderating" on trans
# ✅ Inserted @mannish-ness.bsky.social: It's wild to realize they still can't speak about actual pro-jobs politics of it
# ✅ Inserted @wittmanwatch.bsky.social: Turns out that when your votes throw your “safe” district into chaos and you fob
# ✅ Inserted @jboyd-dc.bsky.social: This is a ridiculous attempt to pigeon -hole what really is a return to the big
# ✅ Inserted @gaspingenemyofgod.bsky.social: Do you understand how insanely bleak it is that politics has become TikTok Theat
# ✅ Inserted @buddyhead.bsky.social: Seems like a lot of you think electoral politics will save us and that shit is p
# ✅ Inserted @heysita.bsky.social: I've worked in a politics and my first degree is PoliSci & Intl Relations. Being
# ✅ Inserted @woodrowforco.bsky.social: All politics is national now.
# ✅ Inserted @thegoblinpoet.bsky.social: my politics really aren't that complicated (an independent Scotland, which is al
# ✅ Inserted @timothypmurphy.bsky.social: it's sort of funny that the person who finally drove the Bush dynasty from Repub
# ✅ Inserted @evanstewart.bsky.social: Wild day for local politics. Big shifts on the Quincy, MA city council, and whil
# ✅ Inserted @stefan-s-from-h.de: Even German TV news reported this. Which is astounding because so far they have
# ✅ Inserted @gaspingenemyofgod.bsky.social: OH FUCKING FANTASTIC, nothing screams “authentic emotional moment” like PRE-GAMI
# ✅ Inserted @lalonde.bsky.social: girls can have little a staying up until 4am to keep up with american politics.
# ✅ Inserted @tanitatikaram.bsky.social: Labour is  truly broken  🥴Bridget Phillipson’s response to Mamdani’s win is to p
# ✅ Inserted @2ndadminstate.bsky.social: Really impressive. Soon comes the hard part, but for now a fighting version of p
# ✅ Inserted @florencehrscott.bsky.social: nobody is talking about mamdani's meteoric rise in light of his belonging to a p
# ✅ Inserted @spectorhairday.bsky.social: A defining characteristic of Zoomers, even the best of them and even those that
# ✅ Inserted @jeffhauser.bsky.social: By contributing to national news cycle, e.g., actual attacks on oligarchs will m
# ✅ Inserted @jeffhauser.bsky.social: Besides primaries (e.g., Mamdani vs. Cuomo, minus ~20 GOP points for Cuomo)...
#
#
# ✅ Inserted @hrryan.bsky.social: But he's just a mayor, and in a very unusual city. I think it's important to kno
# ✅ Inserted @kxraja.bsky.social: Whew. What a beautiful morning to be a brown New Yorker with progressive politic
# ✅ Inserted @fwordleproblems.bsky.social: And also as you point out, 1930s-era moves from an entirely different country ar
# ✅ Inserted @patsweetpat.bsky.social: This just super-extra-mega proves that Trump will outlaw elections.  Only I-- a
# ✅ Inserted @ldea.bsky.social: We don’t read much about Catholics (and their politics) in the US like we used t
# ✅ Inserted @benny-g.bsky.social: Last night Zohran Mamdani said he wished Andrew Cuomo the best in private life a
# ✅ Inserted @pilargomez.bsky.social: That’s a rather wonderful speech.  I am so pleased for New Yorkers to have chose
# ✅ Inserted @ronsupportsyou.mastodon.social.ap.brid.gy: Secretary of War Pete Hegseth: "Today, at the direction of President Trump, the
# ✅ Inserted @dougfiu.bsky.social: Good morning Allie! It definitely is a “Blue Wednesday”. Can’t wait to discuss p
# ✅ Inserted @charravenscroft.bsky.social: I can't really bear to watch most political speeches but this is a must-watch fo
# ✅ Inserted @meadia.bsky.social: No troll the actual losers of last nights elections were not the GOP candidates.
# ✅ Inserted @lyndagood.bsky.social: This wasn’t just one man losing a race it was an entire brand of politics gettin
# ✅ Inserted @harrycleaver.bsky.social: "genuine civic spaces"? You don't understand, the Constitution created a politic
# ✅ Inserted @zenvet23.bsky.social: It's a good day. Well done voters!
#
# ❤️🤍💙
#
# www.cnn.com/politics/liv...
# ✅ Inserted @strandschaf.bsky.social: Vote margin shift across Virginia for the 2025 House elections.
#
# That looks like
# ✅ Inserted @weedle.bsky.social: The deranged wannabe paramilitary commander as a model of decency and integrity
# ✅ Inserted @lyndagood.bsky.social: The real story is that Cincinnati voters just made it clear they’re done with Va
# ✅ Inserted @dharmascholar.bsky.social: TBH, most of the people I know offline don't know half what I do about politics
# ✅ Inserted @northernck.bsky.social: Did Stephen Harper write this budget? Or the leader of @liberalca.bsky.social ?
# ✅ Inserted @levi3d.bsky.social: Obviously, in terms of USA politics, he's very left wing.
#
# The publicly owned gr
# ✅ Inserted @fuckmygaychungus.life: So y'all are just getting involved with politics on an organizational level to "
# ✅ Inserted @evansformaine.bsky.social: Exactly!
#
# Our country is built upon local politics, where people live.
#
# What wo
# ✅ Inserted @queenzaa.bsky.social: Politics is how we boomers fought loneliness. You are absolutely right. A commun
# ✅ Inserted @andrewsparrowgdn.bsky.social: PMQs - snap verdict - www.theguardian.com/politics/liv...
# ✅ Inserted @protector5763.bsky.social: My first impressions are very positive for this young leader. Let’s hope he can
# ✅ Inserted @loafsta.bsky.social: Please expand this into a column:
#
# “FT chief features writer explains why he is
# ✅ Inserted @larpitens.bsky.social: One year after Kamala Harris lost, Virginia has elected their first woman govern
# ✅ Inserted @chucklongisland.bsky.social: How effective will Zohran Mamdani be as NYC mayor? My latest.
# #Mamdani #nyc #po
# ✅ Inserted @scottletteau.bsky.social: Religion is also the large scale, cultural version of a belief system that can b
# ✅ Inserted @suannelqr.bsky.social: Definitely in a cult if you’re demanding every single elected Democrat endorse t
# ✅ Inserted @bluecatlady71.bsky.social: They left one thing out.
# Hire a pedophile, you will get fucked.
#
# We lost polit
# ✅ Inserted @erinpolisci.bsky.social: It’s difficult for a lot of us who live and breathe this stuff to understand thi
# ✅ Inserted @desertphile.bsky.social: Maine protects citizen's rights to vote and have their votes counted.
#
# www.maine
# ✅ Inserted @craigmcintosh.bsky.social: A young, authentic, Democratic Socialist upended legacy status quo Democratic po
# ✅ Inserted @mayor.bsky.social: Pinchable cheeks are the petit objet a of electoral politics
# ✅ Inserted @animalarchaeology.com: The suppression of progressive politics has begun in earnest, I see!
#
# Moderates,
# ✅ Inserted @cordeliawa.bsky.social: Nobody wants another Vance in politics!
# ✅ Inserted @peterflaire.bsky.social: 2025 ELECTION WINS DOMINATED BY DEMOCRATS!
#
# Government shutdown:
# -Blame Trump an
# ✅ Inserted @mtoiv.bsky.social: Nordic moral leadership in world politics in a nutshell:
# ✅ Inserted @chickenpuppet.online: Yes Virginia flipping is very good but also it was driven by Republicans destroy
# ✅ Inserted @rwb22.bsky.social: Nah, this is exactly where I am, I support you in this. It's been stunning to se
# ✅ Inserted @dadsnr.bsky.social: Grew up fascinated by US History, so politics naturally were part of my interest
# ✅ Inserted @mucho-gobbo.bsky.social: After 40 years, you've got it.
#
# Sad but true, people don't like change.
#
# People
# ✅ Inserted @robertsaxton.bsky.social: Today would have been a more fun day to receive a call from Radio Canada for an
# ✅ Inserted @goodmoms.bsky.social: "The Modern Face of Motherhood: Balancing Career and Family as a Working Mom. Fr
# ✅ Inserted @vonneudeck.com: It’s really in professional politics. For a normal person that would be fine. Bu
# ✅ Inserted @libraonfire.bsky.social: Congratulations so well deserved you made political history now show everyone ho
# ✅ Inserted @leonenglish.bsky.social: From everything I can tell looking in from the outside as a monogamous married d
# ✅ Inserted @vaccinenation.bsky.social: Canadians on the whole support anything that might erode Trumps grip on power fo
# ✅ Inserted @scottmarshall.bsky.social: I’m reminded of Kirby rushing down to the street to beat up Nazis who were compl
# ✅ Inserted @canadiian.bsky.social: I’m sure his grandchildren thinks he’s lovely and I’m sure he is. He should go s
# ✅ Inserted @cynphil24.bsky.social: 👇😂🤣😂🤣 Any excuse will do ....... infantile twit.
#
# abcnews.go.com/Politics/tru..
# ✅ Inserted @clh2oars.bsky.social: the one thing we HAVE to keep in mind though is that Mamdani got there because h
# ✅ Inserted @claymorton79.bsky.social: abcnews.go.com/Politics/tru...
#
# Foolish Sack of Shit
# ✅ Inserted @satmarxism.bsky.social: The take away story from the Zohran victory is the 50,000 volunteers and one mil
# ✅ Inserted @wednesdaygj.bsky.social: I keep reading about Mamdani and crying.
#
# It’s been so long since something goo
# ✅ Inserted @scottsuttell.bsky.social: It was an easy election night for Cleveland Mayor Justin Bibb. The interesting s
# ✅ Inserted @averagedoctor.posts.art: I don't have too much to add to the subject, but I'm very glad that Mamdani won
# ✅ Inserted @zkproofs.bsky.social: lol what. no.
#
# Leftism, even though not by itself a particularly coherent term,
# ✅ Inserted @arouet.bsky.social: Keep an eye on Michigan! Abdul El-Sayed is running for Senate with similar polit
# ✅ Inserted @slotsqueen3.bsky.social: It's time for Women to claim their rightful place in American Politics..congratu
#
# 🔍 Searching for 'government' in language 'en' …
#
# 🔍 Searching for 'election' in language 'en' …
#
# 🔍 Searching for 'policy' in language 'en' …
#
# 🔍 Searching for 'réforme' in language 'en' …
#
# 🔍 Searching for 'war' in language 'en' …
#
# 🔍 Searching for 'guerre' in language 'en' …
#
# 🔍 Searching for 'politique' in language 'en' …
#
# 🔍 Searching for 'gouvernement' in language 'en' …
#
# 🔍 Searching for 'élection' in language 'en' …
#
# 🔍 Searching for 'politics' in language 'fr' …
#
# 🔍 Searching for 'government' in language 'fr' …
#
# 🔍 Searching for 'election' in language 'fr' …
#
# 🔍 Searching for 'policy' in language 'fr' …
#
# 🔍 Searching for 'réforme' in language 'fr' …
#
# 🔍 Searching for 'war' in language 'fr' …
#
# 🔍 Searching for 'guerre' in language 'fr' …
#
# 🔍 Searching for 'politique' in language 'fr' …
#
# 🔍 Searching for 'gouvernement' in language 'fr' …
#
# 🔍 Searching for 'élection' in language 'fr' …
#
# 📰 Fetching feed from @bbcnews.bsky.social …
# ✅ 0 posts collected from @bbcnews.bsky.social
#
# 📰 Fetching feed from @reuters.com …
# ✅ 0 posts collected from @reuters.com
#
# 📰 Fetching feed from @apnews.com …
# ✅ 0 posts collected from @apnews.com
#
# 📰 Fetching feed from @nytimes.com …
# ✅ 0 posts collected from @nytimes.com
#
# 📰 Fetching feed from @washingtonpost.com …
# ✅ 0 posts collected from @washingtonpost.com
#
# 📰 Fetching feed from @lemonde.bsky.social …
# ✅ 0 posts collected from @lemonde.bsky.social
#
# 📰 Fetching feed from @liberation.bsky.social …
# ✅ 0 posts collected from @liberation.bsky.social
#
# 📰 Fetching feed from @afp.com …
# ✅ 0 posts collected from @afp.com
#
# 📰 Fetching feed from @cnbc.com …
# ✅ 0 posts collected from @cnbc.com
#
# 📰 Fetching feed from @usatoday.com …
# ✅ 0 posts collected from @usatoday.com
#
# 📰 Fetching feed from @theguardian.com …
# ✅ 0 posts collected from @theguardian.com
#
# 📰 Fetching feed from @latimes.com …
# ✅ 0 posts collected from @latimes.com
#
# 📰 Fetching feed from @edition.cnn.com …
# ✅ 0 posts collected from @edition.cnn.com
#
# 📰 Fetching feed from @wsj.com …
# ✅ 0 posts collected from @wsj.com
#
# 📰 Fetching feed from @60minutes.bsky.social …
# ✅ 0 posts collected from @60minutes.bsky.social
#
# 📰 Fetching feed from @france24.com …
# ✅ 0 posts collected from @france24.com
#
# 📰 Fetching feed from @bfmtv.com …
# ✅ 0 posts collected from @bfmtv.com
#
# 💾 Total inserted: 100 posts into 'news_posts'.

# %%
#   La fonction get_author_feed permet de récupérer les posts d'un 'author' Bluesky.

def get_author_feed(access_token, handle, limit=50, cursor=None):
    url = "https://bsky.social/xrpc/app.bsky.feed.getAuthorFeed"
    headers = {"Authorization": f"Bearer {access_token}"}
    params = {"actor": handle, "limit": limit}

    if cursor:
        params["cursor"] = cursor

    response = requests.get(url, headers=headers, params=params, timeout=10)

    if response.status_code == 200:
        return response.json()
    else:
        print(f"!Error {handle}: {response.status_code} {response.text}")
        return None


# La fonction   permet de récupérer les posts des authors et les sauvegarder dans un fichier json

def fetch_authors_posts(access_token, authors, max_posts_per_author=50, output_file="news_posts.json"):

    all_posts = []

    for handle in authors:
        print(f"\n Récupération des posts de @{handle}...")
        cursor = None
        author_posts = []

        while len(author_posts) < max_posts_per_author:
            data = get_author_feed(access_token, handle, limit=25, cursor=cursor)
            if not data:
                break

            feed = data.get("feed", [])
            if not feed:
                break

            for item in feed:
                post = item.get("post", {})
                record = post.get("record", {})
                text = record.get("text", "")
                created = record.get("createdAt", "")
                print(f"[{created}] @{handle}: {text[:100]}")

                author_posts.append(post)
                all_posts.append(post)

                if len(author_posts) >= max_posts_per_author:
                    break

            cursor = data.get("cursor")
            if not cursor:
                break

            time.sleep(1)

        print(f"✅ {len(author_posts)} posts collectes de @{handle}.")

    with open(output_file, "w", encoding="utf-8") as f:
        json.dump(all_posts, f, ensure_ascii=False, indent=2)

    print(f"\n💾 {len(all_posts)} total posts sauvegardé dans '{output_file}'.")


if __name__ == "__main__":
    # Charger le token
    token = load_token()
    if token:
    # Example list of news accounts on Bluesky
        authors = [
            "bbcnewsnight.bsky.social",
            "reuters.com",
            "apnews.com",
            "lemonde.fr",
            "liberation.fr",
            "nytimes.com",
            "cnn.com",
            "aljazeera.com",
            "usatoday.com",
            "cnbc.com"
            ]

        fetch_authors_posts(token, authors, max_posts_per_author=100)

# %% [markdown]
# TEST 1 :  FOnctionne bien

# %%
def search_posts(access_token, query, lang="en", limit=50, cursor=None):
    """
    Recherche des posts publics sur Bluesky selon un mot-clé et une langue.
    """
    url = "https://bsky.social/xrpc/app.bsky.feed.searchPosts"
    headers = {"Authorization": f"Bearer {access_token}"}
    params = {"q": query, "limit": limit, "lang": lang}

    if cursor:
        params["cursor"] = cursor

    response = requests.get(url, headers=headers, params=params, timeout=10)

    if response.status_code == 200:
        return response.json()
    else:
        print(f"❌ Erreur {response.status_code}: {response.text}")
        return None


def fetch_political_posts(access_token, max_posts=200, output_file="political_posts.json"):
    """
    Récupère des posts sur la politique en anglais et en français.
    """
    topics = ["politics", "government", "election", "policy", "réforme", "politique", "gouvernement", "élection"]
    languages = ["en", "fr"]

    all_posts = []
    seen_uris = set()

    for lang in languages:
        for topic in topics:
            print(f"\n🔍 Recherche de posts '{topic}' en {lang.upper()}...")
            cursor = None

            while len(all_posts) < max_posts:
                data = search_posts(access_token, query=topic, lang=lang, limit=50, cursor=cursor)
                if not data:
                    break

                posts = data.get("posts", [])
                if not posts:
                    print("⚠️ Aucun nouveau post trouvé.")
                    break

                for p in posts:
                    uri = p.get("uri")
                    if not uri or uri in seen_uris:
                        continue

                    seen_uris.add(uri)
                    all_posts.append(p)

                    author = p.get("author", {}).get("handle", "unknown")
                    text = p.get("record", {}).get("text", "")
                    date = p.get("record", {}).get("createdAt", "")
                    print(f"[{date}] @{author}: {text[:80]}")

                    if len(all_posts) >= max_posts:
                        break

                cursor = data.get("cursor")
                if not cursor:
                    break

                time.sleep(1)  # Respecte l'API

    # Sauvegarde des posts dans un fichier JSON
    with open(output_file, "w", encoding="utf-8") as f:
        json.dump(all_posts, f, ensure_ascii=False, indent=2)

    print(f"\n✅ {len(all_posts)} posts sauvegardés dans '{output_file}'.")


if __name__ == "__main__":
    # Charger ton token depuis token.json
    with open("token.json", "r", encoding="utf-8") as f:
        token_data = json.load(f)
        access_token = token_data["accessJwt"]

    fetch_political_posts(access_token, max_posts=300)
# Out:
# 🔍 Recherche de posts 'politics' en EN...
# [2025-11-05T08:57:18.096Z] @alienjawdee.bsky.social: FYI.
# From an Australian perspective.
#
# Dysfunctional Politics in the United Stat
# [2025-11-05T08:57:12.458Z] @therealenzooo.bsky.social: #Republicans look for lessons in an election dominated by #Democratic wins www.n
# [2025-11-05T08:57:11.885Z] @jercor.bsky.social: Nothing like a
# " look over there "
# moment in Tory failed politics.
# [2025-11-05T08:56:55.598Z] @korpivaara.bsky.social: Ok, so right-skewed bias, right there. Also, a „bias“ towards people in their 20
# [2025-11-05T08:56:50.006Z] @shanerosser.bsky.social: #GBNews
#
# www.gbnews.com/politics/us/...
# [2025-11-05T08:56:46.309Z] @akm6.bsky.social: www.cnn.com/politics/liv...
# 💙💙💙💙💙💙💙💙
# [2025-11-05T08:56:32.450Z] @canntoya.bsky.social: At some point the centre left will realise that the way to beat the far right is
# [2025-11-05T08:56:31.981Z] @surprisedface.bsky.social: Bluesky has perfect politics. Every day, the communists fight with the socdems w
# [2025-11-05T08:56:29.654Z] @aknighton.bsky.social: Today's writing is back into The Executioner's Prayer, with priestly politics, f
# [2025-11-05T08:56:27.333Z] @adambienkov.bsky.social: From 'Politics and the English Language' by George Orwell
# [2025-11-05T08:56:21.210Z] @alexvv.bsky.social: This is a beacon shining across the world for the politics of hope.
#
# We have bee
# [2025-11-05T08:56:02.437Z] @whatsup2day.bsky.social: OR FASCISMMM & new Younger Generation VOTERS & Candidates have CHANGED our  poli
# [2025-11-05T08:55:53.524Z] @williamtheconker.bsky.social: So people on the right of politics say the BBC is too left wing and people in th
# [2025-11-05T08:55:48.857Z] @petefrasermusic.bsky.social: …Barnett or Robert Peston who, lest we forget, are meant to know about politics
# [2025-11-05T08:55:27.083Z] @newman123.bsky.social: Over his time in politics aided by the mainstream media in the UK, Farage has be
# [2025-11-05T08:55:16.037Z] @soshobudderfly.bsky.social: Don't forget Boston's incumbent #MayorWu, wins unopposed in the General after tr
# [2025-11-05T08:55:15.161Z] @litterygeniarse.bsky.social: Binding themselves to the lousy deal the Tories did is just bonkers, craven, and
# [2025-11-05T08:54:59.989Z] @susanhypnoreiki.bsky.social: Yuba, Sutter, Glenn, Placer,… I’m a little 🔵 in a 🔴 the County of Yuba.
#
# calmatt
# [2025-11-05T08:54:55.968Z] @lovemilan.bsky.social:  2/2
# Trump and his spineless guardians of Pedophiles party lost them all, from V
# [2025-11-05T08:54:49.311Z] @leadfootlj.bsky.social: Gotta give him & his wife credit ... Liz Cheney is a bad ass to stand up to Seni
# [2025-11-05T08:54:48.362Z] @scottwortley.bsky.social: Was thinking the other day about how bad many contemporary politicians are at th
# [2025-11-05T08:54:22Z] @beyondpunchlines.bsky.social: “Rahul Gandhi’s election rigging claims have shaken the ballot’s very foundation
# [2025-11-05T08:54:21.390Z] @johnmichaelhistory.bsky.social: #OnThisDay 5 November 1331 William Donn de Burgh, 3rd Earl of Ulster stepped dow
# [2025-11-05T08:54:20.512Z] @jamesrball.com: “London and New York, two of the west’s largest, richest, and most diverse citie
# [2025-11-05T08:54:09.234Z] @birthtrauma.bsky.social: Hannah Barnes and Channel 4 have carried out an in-depth investigation of matern
# [2025-11-05T08:54:05.292Z] @shanlonwu.com: Election Night 2025 offers a glimpse of a potential sea change in American polit
# [2025-11-05T08:54:02.000Z] @sz-duras.me.dm.ap.brid.gy: Good work.. Was Marx right? Development and exploitation in 43 countries, 2000–2
# [2025-11-05T08:53:43.199Z] @bebsdotteragain.bsky.social: The fact Mamdani won and democrats have swept the board shows American politicia
# [2025-11-05T08:53:25.748Z] @philwriter.bsky.social: What a wonderful feeling, to be excited by American politics. www.theguardian.co
# [2025-11-05T08:53:16.074Z] @bobbijay.bsky.social: He was never a serious governor choice. Why would he give up the power/money of
# [2025-11-05T08:53:12.810Z] @kittasaurusrex.bsky.social: I divided the sleeves off the sweater* and the politics are a touch less bleak,
# [2025-11-05T08:53:09.504Z] @lhur.bsky.social: Can't we have a rule that anyone that moves away from the UK to Dubai to escape
# [2025-11-05T08:52:17.322Z] @fascinatorfun.bsky.social: Hahahaha
#
# “Could it …? Could it be? Surely not the latest defection? Step forwar
# [2025-11-05T08:52:16.547790Z] @moneywellness.com: We asked our colleagues how easy it is to talk money with their friends. From po
# [2025-11-05T08:52:02.510Z] @murkyclear.bsky.social: Politics are so tricky because some representatives start out well-meaning, and
# [2025-11-05T08:52:02.165Z] @sjharte.bsky.social: As well as questions of loyalty, there was always the suspicion that Catholics i
# [2025-11-05T08:52:01.834Z] @whitneybrown9.bsky.social: And from those of us who support authentic , woke , compassionate politics !
# [2025-11-05T08:50:36.621Z] @chrismollison.bsky.social: You're only as good as your best story.
#
# It's true, no? It's why readers remembe
# [2025-11-05T08:50:33.864Z] @martinwright.bsky.social: Nice to see the Republican Party get a deserved kicking in New York. Less convin
# [2025-11-05T08:50:31.657664+00:00] @mobiquotes.bsky.social: Trust remains the coin of the realm in politics. A President who is trusted, by
# [2025-11-05T08:50:29.611Z] @mralanjohnsmith.bsky.social: Teen Vogue had been a surprising (surprising to me, since it's not on my reading
# [2025-11-05T08:50:28.743Z] @edolis.bsky.social: Serbia aka 'how to turn a corrupt country from russia supporter to useful tool'.
# [2025-11-05T08:50:16.680975+00:00] @mainstream-media.bsky.social: Fox News Poll: How Spanberger won Virginia governor
#
# https://www.foxnews.com/pol
# [2025-11-05T08:50:10.147Z] @animenextseason.com: New post live! 🚀
#
# 👉 animenextseason.com/accel-world-...
#
# The eternal wait for Ac
# [2025-11-05T08:49:58.458Z] @davidquinn.oideachasmedia.com: Almost 900k New Yorkers backed sexual assault, disgusting politics and wild leve
# [2025-11-05T08:49:53.799Z] @lainydelaney.bsky.social: I'm hoping this is the start of the world being better at politics...a girl can
# [2025-11-05T08:49:45.996Z] @melanieselwood.bsky.social: Zohran Mamdani’s win is proof we can stand up to Trumpian politics at the same t
# [2025-11-05T08:49:20.432Z] @shanerosser.bsky.social: #GBNews
#
# www.gbnews.com/politics/sue...
# [2025-11-05T08:48:51.872Z] @ikejnn.bsky.social: ｜[GIFT LINK] The Parents Who Helped Shape Zohran Mamdani’s Politics - NYT - June
# [2025-11-05T08:48:51.030Z] @grazza62.bsky.social: www.thenational.scot/politics/255...
# [2025-11-05T08:48:50.698Z] @scotthanson.de: Actually, I meant that since I'm not from the UK, posts about UK politics are ab
# [2025-11-05T08:48:42.019Z] @onurerdur.bsky.social: Zohran Mamdani is practicing politics the right way.
# [2025-11-05T08:48:41.120Z] @drgeophysics.bsky.social: Oh my.
#
# Even Pennsyltucky ?  Who gets fired in the WH now: www.nbcnews.com/pol
# [2025-11-05T08:48:26.471Z] @tommy-lufc.bsky.social: Yeah but with full respect to Neil, he is a dabbler when it comes to politics. F
# [2025-11-05T08:47:54.319Z] @shanerosser.bsky.social: #GBNews
#
# www.gbnews.com/politics/us/...
# [2025-11-05T08:47:33.245Z] @clemfon.bsky.social: In other words, sheer stupidity and the protection of a small set of priveledges
# [2025-11-05T08:47:25.729Z] @bendo2levi.bsky.social: I don't like talking politics too much because of how effed up everything is but
# [2025-11-05T08:47:14.772Z] @davidwearing.bsky.social: Watch his victory speech for how it gives zero time to the nonsense binary of "i
# [2025-11-05T08:47:13.804Z] @mrjoelclark.bsky.social: Remember, Justin Webb allegedly got the Today job ahead of Ed Stourton because o
# [2025-11-05T08:46:46.557Z] @soshobudderfly.bsky.social: .
# .
# .
# #Kamalaharris urged Californians to vote Yes on #Prop50 .
#
# Thanks for your
# [2025-11-05T08:46:42.511Z] @shanerosser.bsky.social: www.thelondoneconomic.com/politics/wha...
# [2025-11-05T08:46:40.424Z] @drgeophysics.bsky.social: Oh my, even Pennsyltucky? : www.nbcnews.com/politics/ele...
# [2025-11-05T08:46:37.210Z] @lexusvnexus.bsky.social: Fuck You, Trump! From California
# - worst president in history
# - killed more Amer
# [2025-11-05T08:45:36.072Z] @deviousxen.bsky.social: As someone who is not impressed by most politics, especially positively, that wa
# [2025-11-05T08:45:34.081Z] @tchallaforever.bsky.social: This is great.
# When given a reason to turnout, voters will.
# Hopefully this wil
# [2025-11-05T08:45:25.083Z] @animalarchaeology.com: I am sorry for my anti-centrist bigotry and in the future I will do more to make
# [2025-11-05T08:45:05.065Z] @skullcrusher.bsky.social: i don't really follow all politics, but i hope new york enjoys the free bussy fr
# [2025-11-05T08:45:03.139Z] @smiles.bsky.social: Congratulations Zohran, a beacon of light now shines brightly in NYC, across the
# [2025-11-05T08:44:57.732Z] @gain-centre.bsky.social: Today is the day! Join us at 10:00 a.m. to discuss applying for funding in Gende
# [2025-11-05T08:44:31.572Z] @ppni.bsky.social: He took on the whole establishment. The Republican, the Democrat. And he won! 🙌🏻
# [2025-11-05T08:44:25.168Z] @soshobudderfly.bsky.social: .
# .
# .
# #barackobama showed up for the people and help rally voters to the polls i
# [2025-11-05T08:44:18.390Z] @expected-more.bsky.social: At the end of the day the Republic has it's own politics
# [2025-11-05T08:43:22.447Z] @rwalens.bsky.social: So tomorrow we're going to get a bunch of think pieces about how this election w
# [2025-11-05T08:43:15.549Z] @specificityarchives.com: Class politics is climate politics.
# [2025-11-05T08:43:15.137Z] @paisleynclouds.bsky.social: So disappointing to hear this tripe is ‘alive’ in politics.
# Apart from that, he
# [2025-11-05T08:43:15Z] @bluesky.awakari.com:  “New York, tonight you have delivered a mandate for a new kind of politics, a m
# [2025-11-05T08:42:45.180Z] @joenoonan.se: I have a seminar in comparative politics where we discuss democratic development
# [2025-11-05T08:42:15.633Z] @zp39a.bsky.social: One of the problems with celebrity politics is that people put all their hope an
# [2025-11-05T08:42:03.881Z] @nhegday.bsky.social: There’s also this strange loss of wholeness, everyone seems to pick a niche & st
# [2025-11-05T08:41:59.442Z] @willgtu.bsky.social: Scutari Bill Re-Criminalizes Street Marijuana Possession and Unlicensed Legacy O
# [2025-11-05T08:41:51.520Z] @ravreehal.bsky.social: Hopefully a change for the better in politics. Something to lift the recent righ
# [2025-11-05T08:41:50.012Z] @braidsinspades.bsky.social: “…perhaps the most potent examples of violent innocence involve national politic
# [2025-11-05T08:41:28.104Z] @rickyhaggett.bsky.social: What american politics word is everyone looking up this morning? I just found ou
# [2025-11-05T08:41:25.822Z] @sstrumello.bsky.social: Democratic U.S. Rep. Mikie Sherrill defeats Ciattarelli in hotly contested N.J.
# [2025-11-05T08:41:21.260Z] @simoncosgrove.bsky.social: Day 2105 of #Brexit: ‘Nige got under way. His main theme was that the country wa
# [2025-11-05T08:41:15.415Z] @davekflynn.bsky.social: It must feel nice to have someone in politics to be excited about…
# [2025-11-05T08:41:06.989Z] @soshobudderfly.bsky.social: .
# .
# .
# #MarySheffield  makes history as the first woman elected mayor of #detroit
# [2025-11-05T08:40:21.735Z] @andybirss.bsky.social: Justin Webb is quite happy to bring up errors/mistakes that politicians have mad
# [2025-11-05T08:40:20+00:00] @us-ny-nb.bsky.social: What does Mamdani’s win mean for the future of the Democratic Party? | Politics
# [2025-11-05T08:40:05.824Z] @cesarferraro.bsky.social: There's no avoiding the fact that postmaterialism dominates politics now, so one
# [2025-11-05T08:40:03.864Z] @delexical.bsky.social: Seriously. If you want an insight into the voters of the 5 boroughs of NYC in th
# [2025-11-05T08:39:54.961Z] @thefatfryer.bsky.social: Politics is about choices. To not put this case for the EU or a future vision fo
# [2025-11-05T08:39:52.287Z] @carolinedegruyter.bsky.social: “I am tired of people who believe in democracy and the rule of law just sitting
# [2025-11-05T08:39:18.807Z] @ironlung420.bsky.social: Nah, Islam needs to embrace Democrats policies.. And keep Christianity out of my
# [2025-11-05T08:39:15.303Z] @darthsatoris.bsky.social: As a European resident, I shouldn't have to be as invested in American politics
# [2025-11-05T08:39:14.199Z] @cleonaw.bsky.social: Yes!! This is the beginning of a wave of socialist politics for the people not t
# [2025-11-05T08:39:10.791Z] @tommyboy0690.bsky.social: California voters approve Democratic-drawn congressional map www.nbcnews.com/pol
# [2025-11-05T08:38:44.291Z] @gardengirld.bsky.social: www.sfchronicle.com/politics/joe...
# #trump
# #CAProp50
# [2025-11-05T08:38:24.385Z] @jamesblurbs.bsky.social: He suggests an affinity to Green politics in your screenshot. Regardless, I don’
# [2025-11-05T08:38:11.875Z] @segfaultvicta.aludel.xyz: ...it calls into question one's ability to correctly read any other damned thing
# [2025-11-05T08:37:43.345Z] @brandoninvergo.bsky.social: Normally I'm a bit annoyed when my carefully curated feed gets swamped by politi
# [2025-11-05T08:37:29.738Z] @daveashleypoet.bsky.social: #jolliness #emoetry #poem #politics #slown #cankles #resist
# [2025-11-05T08:37:26.275Z] @adilray.bsky.social: As a Muslim, at a time of division Mamdani has brought much of his city together
# [2025-11-05T08:37:21.438Z] @andrewwr235.bsky.social: I'm really pleased by this.
#
# A triumph for adult politics over infantile and sen
# [2025-11-05T08:36:44.639Z] @monolithfiji.bsky.social: man it sure feels good being on the right side of politics baby
# [2025-11-05T08:36:39.497Z] @sith-art.bsky.social: All the worst people in politics are going to take all the wrong lessons away, i
# [2025-11-05T08:36:37.126Z] @acap42.bsky.social: As a New Yorker and Londoner - and new @greenparty.org.uk member - I couldn't be
# [2025-11-05T08:36:31.019Z] @bawsman.bsky.social: I‘ve had enough of charisma politics and politicians, thanks ever so much.
# [2025-11-05T08:36:19.546Z] @maggiechapman.bsky.social: The job of the radical is to make hope possible rather than despair convincing!
#
# [2025-11-05T08:36:03.582Z] @theangelofhistory.bsky.social: The old English custom of “you don’t discuss religion or politics in the workpla
# [2025-11-05T08:36:00.436Z] @lalonde.bsky.social: can anyone good at politics tell me if this means we get Transgender For Everybo
# [2025-11-05T08:35:57.740Z] @ukrainewarpod.bsky.social: I’d just add that politics don’t stop in autocracies, as much as Trump would lik
# [2025-11-05T08:35:22.289Z] @newschambers.bsky.social: How are you going to help people understand what actually happened if your go-to
# [2025-11-05T08:35:13.587Z] @theatredesvampire.bsky.social: as someone who has been keeping up with nyc’s politics nearly as much as my home
# [2025-11-05T08:35:03.060Z] @cordelia-dechair.bsky.social: Rachel wants to do the right thing and punch down.  That’s what grown-up politic
# [2025-11-05T08:34:09.301Z] @elmaestrotaino.bsky.social: Not just “right now” - we don’t want him or his kind of politics for the wealthy
# [2025-11-05T08:34:00.093Z] @alexislouise-35.bsky.social: Donald trump, pack your bags your being evicted. Your prison cell is waiting.
#
# A
# [2025-11-05T08:33:34.880Z] @jesselgriffiths.bsky.social: Well worth a read - Thomas Piketty on populism, politics and Keir Starmer
# [2025-11-05T08:33:25.645Z] @robduncan.bsky.social: #USPOL #USA #us #uspoli #poli #politics #cdnpoli #canada #MidasMighty #america #
# [2025-11-05T08:33:21.169Z] @mm-hacker-news.bsky.social: Zohran Mamdani wins the New York mayoral race
# https://www.nbcnews.com/politics/e
# [2025-11-05T08:32:53.788162+00:00] @toppnews.bsky.social:
# #attack   #budget   #China   #politics   #reforms   #stock markets   #Tariffs
# [2025-11-05T08:32:50.332Z] @voyageinfini.bsky.social: Exactly, and untether healthcare from employment so that everyone is covered reg
# [2025-11-05T08:32:11.897Z] @santanumalbum.bsky.social: www.wsj.com/politics/ele...
# [2025-11-05T08:32:07.858Z] @soshobudderfly.bsky.social: .
# .
# .
# It's barely 12 hours post-results and already picking an issue that was ne
# [2025-11-05T08:32:06.920Z] @loveofthesun.bsky.social: newsom did not push for prop 50 for "justice", he pushed for it because it benef
# [2025-11-05T08:32:00.173Z] @drgeophysics.bsky.social: Jetman in the news: The blinding illegality, incompetence and stupidity of these
# [2025-11-05T08:32:00.110Z] @edsbenedict.bsky.social: Great piece. For those of us on the outside who can’t see the way the politics f
# [2025-11-05T08:31:59.456Z] @mylifeasabook.bsky.social: While, once again, more than half of white people suck...
#
# This is FANTASTIC!
#
# W
# [2025-11-05T08:31:53.924Z] @sanssouci.bsky.social: i was thinking the exact same thing this very moment,  scrolling the daily news
# [2025-11-05T08:31:52.299Z] @theotherstu.co.uk: And as is showing in politics, people are easily led by shiny things and boats.
# [2025-11-05T08:31:48.459Z] @beckyaizen.bsky.social: Also someone should tell him that identity politics is soooo 2020.
# [2025-11-05T08:31:43.859Z] @sayiayia.bsky.social: Get rid of that old school politics!
# [2025-11-05T08:31:19.818Z] @bs.mivox.net:
# [2025-11-05T08:31:16.187Z] @robduncan.bsky.social: www.youtube.com/watch?v=9OtO...
#
# #USPOL #USA #us #uspoli #poli #politics #cdnpol
# [2025-11-05T08:31:09.825Z] @wondersnorbet.bsky.social: Bet they did, how many Nazis are in NY city who voted on the Trump side of polit
# [2025-11-05T08:30:50.062Z] @mrianmcconnell.bsky.social: ♦️While there is no shortage of people who for political reasons seem to delight
# [2025-11-05T08:30:46.318Z] @teedixie.bsky.social: I think he’ll be just fine. Americans are different, they love a performance, a
# [2025-11-05T08:30:23.209Z] @rogger.bsky.social: Although inasmuch as UK politics has a rhetoric problem I suspect the weak sayin
# [2025-11-05T08:30:18.987Z] @spring-tulip.bsky.social: Old corrupted Democratic elites will eventually retire from politics, time for n
# [2025-11-05T08:30:14.120Z] @acarpen.bsky.social: Furthermore, as Geoff Mulgan points out, where are the cultural roots feeding in
# [2025-11-05T08:29:17.795Z] @anarchoshanties.bsky.social: I know absolutely nothing about Ossoff except that apparently he's bringing toge
# [2025-11-05T08:29:02.609Z] @robduncan.bsky.social: #USPOL #USA #us #uspoli #poli #politics #cdnpoli #canada #MidasMighty #america #
# [2025-11-05T08:29:02.321Z] @bozsle33.bsky.social: #politics
#
# I'm so happy for multitude of reasons that in the US many progressive
# [2025-11-05T08:28:18.352Z] @smoooooveoper8tor.bsky.social: BOOM! The Blue wave is coming to wash every Cowardly RethugliKKKlan stain out of
# [2025-11-05T08:28:12.182Z] @tay-unrushed.bsky.social: Nah it would get religious people (particularly Christians) to think that politi
# [2025-11-05T08:28:04.832Z] @alexvv.bsky.social: The guy has a mountain to climb, but it's great that he's been given the opportu
# [2025-11-05T08:27:23.783Z] @suescishaw.bsky.social: Completely misses the point that the vast majority of the public are not followi
# [2025-11-05T08:27:19.058Z] @jervasioderivia.bsky.social: Can’t remember the last time I felt hopeful about anything in international poli
# [2025-11-05T08:27:13.687Z] @grrlscientist.bsky.social: MAGA is proof that we need to invest A LOT MORE IN EDUCATION
#
# #politics #MAGAts
# [2025-11-05T08:27:09.681Z] @smoooooveoper8tor.bsky.social: BOOM! The BLUE is coming to wash every cowardly RethugliKKKlan stain out of poli
# [2025-11-05T08:27:08.641Z] @stigmergy.bsky.social: To this European, Mandani’s victory looks like a rejection of the entire politic
# [2025-11-05T08:27:05.440Z] @tylerontheinternet.bsky.social: You would know this if you weren't a complete hack-fraud out of your depth. The
# [2025-11-05T08:25:50.921Z] @oldboots.bsky.social: www.threads.com/@desi_antisp...
# THE ONLY WAY TO GET POLITICIANS THAT REPRESENT T
# [2025-11-05T08:25:43.233Z] @nkfinity.bsky.social: Lots of users here who're super passionate about politics but apparently have ne
# [2025-11-05T08:25:35.966047+00:00] @bigearthdata.bsky.social: Zohran Mamdani's Silent Climate Politics
# ->Heatmap News | More from Lil Dr Glen
# [2025-11-05T08:25:07.995Z] @hsvedang.bsky.social: Reeves’s great gamble is that she can yet restore their faith by proving that cr
# [2025-11-05T08:24:43.360Z] @quibilah.bsky.social: www.thetimes.com/uk/politics/...
# [2025-11-05T08:24:37.460Z] @les-spaceman.bsky.social: Wes Streeting says NHS staff are having to bear a return to 70s racism - you sho
# [2025-11-05T08:24:29.345Z] @climate.skyfleet.blue: Zohran Mamdani’s Silent Climate Politics #Climate
# [2025-11-05T08:23:18.155Z] @tommyboy0690.bsky.social: NBC News Exit Poll: Voters disapprove of Trump in New Jersey, Virginia and other
# [2025-11-05T08:23:06.950Z] @usmansmith.bsky.social: Politics without the violence?
# [2025-11-05T08:23:02.001Z] @michaeljsc.bsky.social: Like, no one’s identity is “I’m from England and Wales”. It’s an administrative
# [2025-11-05T08:23:01.181Z] @markjonesvet.bsky.social: Moral panic or measured response? The politics behind South Africa’s elephant ‘c
# [2025-11-05T08:22:52.406Z] @watershipdown-72.bsky.social: Trickle down politics? J.D. is toxic.
# [2025-11-05T08:22:39.001Z] @pastpresentsoc.bsky.social: From the current issue: “Viewpoint: Ordinary Politics in Late Medieval Europe”
#
#
# [2025-11-05T08:22:32.857Z] @natasharedmane.bsky.social: Lula's party functions in a very similar way as the Democrats, both politically
# [2025-11-05T08:22:30.766Z] @acdpc.bsky.social: This speech is so inspiring! If you haven’t heard the entire speech, grab a cup
# [2025-11-05T08:21:58.586Z] @by698q.bsky.social: And while minor to some, Seattle kept its democratic mayor rejecting an unqualif
# [2025-11-05T08:21:57.815Z] @empty52.bsky.social: The only way to stop them from F-ing it up is to extract AIPAC and other lobbyis
# [2025-11-05T08:21:43.883Z] @licjar.bsky.social: https://www.nbcnews.com/politics/2025-elections/new-york-city-mayor-results
# もう一つ
# [2025-11-05T08:21:35.515Z] @mrcontrariwise.bsky.social: Nice work, man. Shoulda followed you a while ago when we saw that at least *some
# [2025-11-05T08:21:27.156Z] @thedaxsymbiont.bsky.social: When I use the word liberal it is not strictly an insult but also isn’t a comple
# [2025-11-05T08:21:21.276Z] @fromthemorgue.bsky.social: So it turns out that left politics *has* been locked up by a stultifying elite c
# [2025-11-05T08:21:13.045Z] @kprclc.bsky.social: Good on you.
# I wish more US voters would come to that realisation.
#
# I'm watching
# [2025-11-05T08:20:53.695Z] @delaneylux.bsky.social: you have no idea how fucking excited I am
#
# im not even in NYC, im upstate, but i
# [2025-11-05T08:20:53.493Z] @canaries-captionit.bsky.social: Glad Mamdani won in New York but the notion this is a massive shift in politics
# [2025-11-05T08:20:52.608Z] @luna2nodrama.bsky.social: Morning.
# A good day huh.
#
# Let's all get down to Keith's gaffs and celebrate.
#
#
# [2025-11-05T08:20:50.449Z] @demiurg.bsky.social: People want a future and politics for the people and by the people, not fascism.
# [2025-11-05T08:20:40.144Z] @2c-ornot2c.bsky.social: Nonsense. VA and NJ are moderates. But what WAS universal was affordability. Jus
# [2025-11-05T08:20:38.917Z] @orko.bsky.social: Really makes you wonder when Rishi is gonna finally take the L and stop trying t
# [2025-11-05T08:20:21.125Z] @maggslondongirl.bsky.social: This brings us HOPE that the tide is turning on the hateful, divisive, politics
# [2025-11-05T08:20:16.793Z] @bbctopmeninheat.bsky.social: www.nbcnews.com/politics/202...
# [2025-11-05T08:20:14.831Z] @jeanjacovella.bsky.social: Dans le monde selon Trump…
# « L’absence de Trump sur les bulletins de vote et le
# [2025-11-05T08:20:10.898Z] @anarch0striga.bsky.social: Today was a good day for electoral politics 🔥 But the need for everyday, on the
# [2025-11-05T08:20:01.684Z] @jamiehew.bsky.social: I agree with your politics but I utterly refute your closing down of other voice
# [2025-11-05T08:19:31.101Z] @thebiggoldfish.bsky.social: MTG is not to be trusted, the only reason she's changed tack is because she know
# [2025-11-05T08:19:23.469Z] @suzybie.bsky.social: We need new voices analysing US politics in Irish media.
# [2025-11-05T08:19:07.542Z] @thisisdogs.bsky.social: I try not to comment on US politics cause I don't live there but man is it nice
# [2025-11-05T08:18:33.818Z] @jelenawoehr.bsky.social: Research time
# [2025-11-05T08:17:33.052Z] @mercedesmonelatest.bsky.social: #trending #politics #stfunigga
# [2025-11-05T08:17:21.776Z] @grrlscientist.bsky.social: Dick Cheney is DEAD. May the one million murdered souls of Iraq haunt you foreve
# [2025-11-05T08:17:11.634Z] @baileysam.bsky.social: www.mediaite.com/politics/it-...
# [2025-11-05T08:17:00.222Z] @ihavethatonvinyl.com: who is this "we" you speak of? what did you do? you just  offer your mealy mouth
# [2025-11-05T08:16:36.811Z] @rotster.bsky.social: I know it’s not really the point, but every time I see something from Zohran, I
# [2025-11-05T08:16:33.551Z] @joshdaniel.bsky.social: Him and Polanski showing that people want direct empathy and decency as a centra
# [2025-11-05T08:16:10.753Z] @brokensymmetry.art: What's liberal about annoying conservatives, helping kids and teaching practical
# [2025-11-05T08:16:04.278Z] @privatechand.bsky.social: This is across the board true for feminist politics and TERFs, transphobes and s
# [2025-11-05T08:15:56.302Z] @julijuxtaposed.bsky.social: ‘7 election takeaways — from Trump the foil to post-cancellation politics’ www.p
# [2025-11-05T08:15:09.301Z] @mimi9324.bsky.social: I haven’t seen people engaging leftist and progressive elected officials. Which
# [2025-11-05T08:14:58.009Z] @mrsbundrige.bsky.social: You couldn’t wait a week? A month? Hell 24 hours?  You threw water on the bonfir
# [2025-11-05T08:14:29.506Z] @kabbman.bsky.social: Nick Ferrari on LBC will try to join the dots with Khan. Stating first he is not
# [2025-11-05T08:13:59.757Z] @gthanku.bsky.social: some of them probably did it as cynical politics but it doesn't matter one bit,
# [2025-11-05T08:13:49.635Z] @brendering.bsky.social: "We won because we insisted that no longer would politics be something that is d
# [2025-11-05T08:13:38.018Z] @marymcnamara.bsky.social: I hear what you are saying but I’m so so beyond caring. I’ve been following poli
# [2025-11-05T08:13:32.851Z] @justinfarrimond.bsky.social: Morning All!
#
# Today's going to be a cracker.
# Hopefully.
#
# Here, read this.  Nowt
# [2025-11-05T08:13:28.983Z] @sandy.meangirls.online: have we showed the suburban winemoms thirsty for the blood of republicans this y
# [2025-11-05T08:13:27.221Z] @stormyauror.bsky.social: I think everything—politics, economics, even some version of physics, comes down
# [2025-11-05T08:13:08.009Z] @uspol.skyfleet.blue: Politics of Who Rather Than What | Interview: Yuval Levin
# [2025-11-05T08:13:03.341Z] @sophiemac.bsky.social: Have you seen? And guess what? The BBC isn't carrying this story, even though Th
# [2025-11-05T08:12:51+00:00] @uk-nb.bsky.social: ‘Serious gaps’ in Labor’s environment laws undermine attempt to fix broken syste
# [2025-11-05T08:12:36.169Z] @scribblerrob.bsky.social: Breaking my no politics policy just to say well done America for opening a few d
# [2025-11-05T08:12:34.789Z] @maggiekimline.bsky.social: Argh, once again an influx of locals following me, all American political accoun
# [2025-11-05T08:12:30.623Z] @mindimmock.bsky.social: Australians now identify as Christian. Religious groups should have no privilege
# [2025-11-05T08:12:20.563Z] @bobbelcherofvt.bsky.social: www.motherjones.com/politics/202...
# [2025-11-05T08:12:10.586Z] @vannibattenberg.bsky.social: Okay so like I'm not that up to date on American politics, cause I keep my curta
# [2025-11-05T08:11:25.655Z] @sgeez.bsky.social: Scrubbing the right-wing democrats and not participating in their weak politics
# [2025-11-05T08:11:21.047Z] @capncuster.bsky.social: We also have Truman, FDR, JFK, Carter, Obama and many fine individuals at all le
# [2025-11-05T08:11:01.364Z] @peterrelph.bsky.social: When Trump has control of the Supreme Court; ignores the Constitution entirely,
# [2025-11-05T08:10:58.843Z] @willgtu.bsky.social: All Jewish councils in key New Jersey area endorse Jack Ciattarelli for governor
# [2025-11-05T08:10:57.519Z] @polyglottos.bsky.social: I wasn't cognizant, at least not on politics, as I was 4. But even I know that n
# [2025-11-05T08:10:44.971Z] @khalid4ewh.bsky.social: Freeze rents? Free buses? Ask the wealthy to pay a bit more?
#
# These are popular
# [2025-11-05T08:10:39.331Z] @regipsaloquitur.com: Remember, frens: when one Party member gets attacked, we ALL roll for initiative
# [2025-11-05T08:10:21.965Z] @annharries.bsky.social: I cannot recommend this pod highly enough. It’s a Hedy mix of culture, music, ph
# [2025-11-05T08:10:20.000Z] @actualtorgo.threads.net.ap.brid.gy: NYTimes still sometimes gets it: https://www.nytimes.com/2025/11/04/us/politics/
# [2025-11-05T08:10:16.045Z] @bevrijdingspiegel.bsky.social: I know nothing about Virginia's politics or these races, but would you really bo
# [2025-11-05T08:10:00.383Z] @srd.bsky.social: And, as you know, this was replicated and strengthened in colonial states - espe
# [2025-11-05T08:09:50.229Z] @dangerwithin.bsky.social: @realdonaldrump.bsky.social You could stop the stock market crash with the strok
# [2025-11-05T08:09:48.345Z] @dozo27.bsky.social: Today voters resoundingly rejected Trump and Trumpism, and tomorrow, politics wi
# [2025-11-05T08:09:10.569Z] @chilterngreens.bsky.social: Southwark Councillor Kath Whittam on defecting from Labour to Greens: “I can bre
# [2025-11-05T08:08:50.186Z] @fnafilms.com: Mamdani has provided the corporate Dems with a “shit or get off the pot” moment.
# [2025-11-05T08:08:47.517Z] @grrlscientist.bsky.social: Mike Johnson: Pedo Protector-in-chief
#
# #Politics #PedoProtector #GOP #rethuglica
# [2025-11-05T08:08:45.159Z] @gotdiva.bsky.social: calmatters.org/politics/ele...
# [2025-11-05T08:08:42.979Z] @taniapdx.bsky.social: I've only ever seen NYC from the air, but this gives me such joy. Mamdani is exa
# [2025-11-05T08:08:27.109Z] @gregianjohnson.bsky.social: Politics through the lens of videos that could have been taken in the capital ci
# [2025-11-05T08:08:25.257Z] @everalexander.bsky.social: I do not talk politics in work target, but this is country of immigrants
# [2025-11-05T08:08:18.241Z] @bad-faerie.bsky.social: Jeysús crisps, Sky (JonCraig) are trotting out ReFuk fantasy politics now.
# In 1
# [2025-11-05T08:07:41.320Z] @judgyjudes.bsky.social: Ohhh, tell us more about the politics of those shooters.
# [2025-11-05T08:07:25.538Z] @ainzeta.bsky.social: this is the most i've posted about politics in years but tonight's a night that'
# [2025-11-05T08:07:11.530Z] @jetthedrake.bsky.social: Lets make no bones about it either
# The Democrats did nothing to help or support
# [2025-11-05T08:07:10.829Z] @henriklarsen.bsky.social: The American people sent a clear message to the president and the Republican Par
# [2025-11-05T08:06:46.850Z] @isaacgantwerkmayer.bsky.social: fair enough, and I'm sorry about assuming it was an intentional misspelling. and
# [2025-11-05T08:06:25.934Z] @kezzcat.bsky.social: It's a rare thing to feel hopeful in this world, and especially in this country.
# [2025-11-05T08:06:13.661Z] @heatmap.news: Zohran Mamdani ran an ultra-disciplined campaign for mayor — one that barely tou
# [2025-11-05T08:06:12.373Z] @jonathanlack.bsky.social: You don’t have to have Zohran’s exact politics to succeed. But if you aren’t wil
# [2025-11-05T08:06:10.951Z] @sdotcarter.bsky.social: Threw her under the bus before the numbers were in. I LOVE TO SEE IT. 🩵💙🩵💙🩵💙🩵💙🩵💙
# [2025-11-05T08:05:50.009Z] @malcolmmckinsey.bsky.social: Arizona teachers' costumes weren't about Charlie Kirk. They're facing death thre
# [2025-11-05T08:05:44.861Z] @terriblepie.bsky.social: Turns out that I, a blob living in the north of the UK,had quite a bit of emotio
# [2025-11-05T08:05:38.282Z] @bensouthwood.com: Try and avoid politics on here, but what a wonderful video. Everything seems to
# [2025-11-05T08:05:28.582Z] @dom96.picheta.me: Congrats to Mamdani on a wonderful campaign. Nice to finally see some hope in ou
# [2025-11-05T08:05:21.949Z] @liverpoolcomrade.bsky.social: Haha Brits and Americans don't always get along on bsky due to ignorance of each
# [2025-11-05T08:05:06.472Z] @bobappleyard.bsky.social: hottest couple in politics, what can you do
# [2025-11-05T08:05:01.668Z] @davefr.bsky.social: US politics generally does not feature heavily.
# Obviously Trump saying dumb thin
# [2025-11-05T08:04:56.951Z] @kythra.bsky.social: of voters were only willing to give trump a very short leash to fix the economy
# [2025-11-05T08:04:48.487Z] @jimt1877.bsky.social: This is encouraging, not only for US citizens but for the British, too. With the
# [2025-11-05T08:04:44.038Z] @saoirsemc.bsky.social: I should know better than to even think about US politics but the NY mayor elect
# [2025-11-05T08:04:35.055Z] @kadath.bsky.social: I don’t talk much about politics anymore, mostly because I don’t know what to sa
# [2025-11-05T08:04:28.125Z] @crustyfox05.bsky.social: Somehow that’s even worse. I think I’ll stick with toxic ass politics instead.
# [2025-11-05T08:04:26.190Z] @charlottor.bsky.social: Incredibly rare in politics full stop, and I’m wholly convinced it’s a big part
# [2025-11-05T08:04:03.020Z] @falkoopa.in: I can't speak about Harry Potter but I don't think Trans people will be the focu
# [2025-11-05T08:03:56.172Z] @highcountryrose.bsky.social: This is becoming a reference thread for me for electoral wins. Folks keep coming
# [2025-11-05T08:03:14.909Z] @nfornihilism.net: now we've all had fun today, it's been a special occasion and undoubtedly the am
# [2025-11-05T08:03:05.127Z] @stuartelden.bsky.social: Lee Manion, The Recognition of Sovereignty: Politics of Empire in Early Anglo-Sc
# [2025-11-05T08:03:05.105Z] @adrianburt.bsky.social: Well we could erase politics by living under a totalitarian autocracy where no o
# [2025-11-05T08:03:01.776Z] @brandaid-world.bsky.social: Thank you to Black and Brown New Yorkers for giving me hope in politics 🙏 New Yo
# [2025-11-05T08:02:54.468Z] @ringtheory.bsky.social: Now that Mamdani won, can we please hold Governor Newsom accountable and *not* e
# [2025-11-05T08:02:51.641Z] @logan.hater.club: The Bob Nightengale of politics
# [2025-11-05T08:02:39.214Z] @andygjburge.bsky.social: Of course not, with the honourable exception of Vic Derbyshire who did interview
# [2025-11-05T08:02:14.114Z] @jkaffash.bsky.social: It blows my mind how a piece of writing from 1963 can be so prescient, so perfec
# [2025-11-05T08:02:11.601958+00:00] @longtail.news: Feed: "Environmental Politics Journal"
# By: Charlotte Weatherill on Tuesday, Nove
# [2025-11-05T08:02:08.836Z] @andymcdonaldmp.bsky.social: Congratulations to @zohrankmamdani.bsky.social on your inspiring victory! 🌹
#
# He
# [2025-11-05T08:02:08.504Z] @tadaaa.bsky.social: This really resonates - the utter supine, complacent & compliant (terrified) nat
# [2025-11-05T08:02:00.603200+00:00] @longtail.news: Feed: "Environmental Politics Journal"
# By: Charlotte Weatherill on Wednesday, No
# [2025-11-05T08:01:53.411Z] @lilliantj.bsky.social: "But in fact, today voters resoundingly rejected Trump and Trumpism, and tomorro
# [2025-11-05T08:01:42.138Z] @waynepatriot.bsky.social: As usual, The Daily Buttwipe (Daily Mail) is downplaying the blue tsunami of las
# [2025-11-05T08:01:38.614Z] @grahammuir.bsky.social: www.nbcnews.com/politics/202...
# [2025-11-05T08:01:24.697Z] @theresonlyone1.bsky.social: It's time for Democrat party leaders to get the fuck out of politics and let the
# [2025-11-05T08:01:20.237Z] @castrogacio.bsky.social: I thought speeches like these were only in the movies. I was mistaken!
#
# What's c
# [2025-11-05T08:01:13.336Z] @alana-m-vincent.net: The way Mamdani drew on history in his campaign is obviously super satisfying to
# [2025-11-05T08:01:10.870Z] @cameronclark.bsky.social: It’s easy to be outspoken when your politics are popular and the conventional wi
# [2025-11-05T08:01:09+00:00] @conflicts.bsky.social: Virginia governor election results | CNN Politics
#
# https://www.europesays.com/25
# [2025-11-05T08:00:47.801Z] @2fast2quick.bsky.social: Truly a perfect natural experiment, where the only variable is moderate vs progr
# [2025-11-05T08:00:41.484Z] @armchairshrink.bsky.social: That said I think it's pretty rich that you don't follow UK politics by your own
# [2025-11-05T08:00:34.297Z] @ankemarsh.bsky.social: Zohran Mamdani, mayor of NYC!!!
#
# He ran on policies to help people
#
# He did not t
# [2025-11-05T08:00:25.177Z] @mirkkawrites.bsky.social: Hope over big money and small ideas.
# [2025-11-05T08:00:22+00:00] @europesays.bsky.social: Virginia governor election results | CNN Politics
#
# https://www.europesays.com/25
# [2025-11-05T08:00:20.486149+00:00] @mainstream-media.bsky.social: AOC says Trump stopped MTG's potential Senate run, sparking her 'revenge tour' a
# [2025-11-05T08:00:15.520Z] @almagroschool.bsky.social: I know that it's politics and you have to make an effort esp in the US but I fin
# [2025-11-05T08:00:11+00:00] @eupolitics.bsky.social: Virginia governor election results | CNN Politics
#
# https://www.europesays.com/25
# [2025-11-05T08:00:05.878386+00:00] @blackmetaltrump.bsky.social: "Trumpian Shadows Over Greene's Eldritch Vengeance"
# https://www.foxnews.com/pol
# [2025-11-05T07:59:58.103Z] @bdowney.bsky.social: Amen.
#
# I live to see baddies eat shit.
#
# I woke up this morning and thought, "I
# [2025-11-05T07:59:48.355Z] @nsousanis.bsky.social: "because we insisted that no longer would politics be something that is done to
# [2025-11-05T07:59:40.675Z] @faolanmcean.bsky.social: I really wish I didn't have to care about US politics, but seeing Mamdani run on
# [2025-11-05T07:59:35.023Z] @redskyforge.bsky.social: Great news from New York, California and Virginia. From this side of the Atlanti
# [2025-11-05T07:59:07.552Z] @benwray1989.bsky.social: The billionaire class through a lot of $$$ at stopping this from happening and f
# [2025-11-05T07:59:04.232Z] @opiniontoday.bsky.social: The Voters Who Propelled Mamdani to Victory.
# (Wall Street Journal-unlocked)
# www.
# [2025-11-05T07:58:50.817Z] @cameronclark.bsky.social: I said a similar thing about Taylor Swift, who was outspoken about politics in t
# [2025-11-05T07:58:41.585Z] @kythra.bsky.social: and predictibly at least a solid majority of  them will flee ship for the other
# [2025-11-05T07:58:25.234Z] @romanpiso.bsky.social: @paulinsc.bsky.social @hermes61.bsky.social #Discover #News #📰News #Politics #Po
# [2025-11-05T07:57:59.687Z] @catpotus.bsky.social: PARTY like it's 1969
#
# Not since 1969 the most votes for NYC Mayor
#
# Politics from
# [2025-11-05T07:57:54.372Z] @environmentalpol.bsky.social: New guest post!
#
# Internal city climate leadership: Creating meaning from dilemm
#
# 🔍 Recherche de posts 'government' en EN...
#
# 🔍 Recherche de posts 'election' en EN...
#
# 🔍 Recherche de posts 'policy' en EN...
#
# 🔍 Recherche de posts 'réforme' en EN...
#
# 🔍 Recherche de posts 'politique' en EN...
#
# 🔍 Recherche de posts 'gouvernement' en EN...
#
# 🔍 Recherche de posts 'élection' en EN...
#
# 🔍 Recherche de posts 'politics' en FR...
#
# 🔍 Recherche de posts 'government' en FR...
#
# 🔍 Recherche de posts 'election' en FR...
#
# 🔍 Recherche de posts 'policy' en FR...
#
# 🔍 Recherche de posts 'réforme' en FR...
#
# 🔍 Recherche de posts 'politique' en FR...
#
# 🔍 Recherche de posts 'gouvernement' en FR...
#
# 🔍 Recherche de posts 'élection' en FR...
#
# ✅ 300 posts sauvegardés dans 'political_posts.json'.

# %% [markdown]
# TEST 2 :  FOnctionne bien

# %%
def fetch_political_news(access_token, query="politics OR politique OR government", limit=50, max_posts=200):
    """
    Fetch posts about political news from Bluesky.
    """
    url = "https://bsky.social/xrpc/app.bsky.feed.searchPosts"
    headers = {"Authorization": f"Bearer {access_token}"}

    all_posts = []
    cursor = None

    while len(all_posts) < max_posts:
        params = {"q": query, "limit": limit}
        if cursor:
            params["cursor"] = cursor

        r = requests.get(url, headers=headers, params=params, timeout=10)
        if r.status_code != 200:
            print("❌ Error:", r.status_code, r.text)
            break

        data = r.json()
        posts = data.get("posts", [])
        if not posts:
            print("No more posts found.")
            break

        for post in posts:
            record = post.get("record", {})
            author = post.get("author", {}).get("handle", "unknown")
            text = record.get("text", "")
            created = record.get("createdAt", "")
            print(f"[{created}] @{author}: {text[:100]}")
            all_posts.append(post)

            if len(all_posts) >= max_posts:
                break

        cursor = data.get("cursor")
        if not cursor:
            break

        time.sleep(1)

    with open("political_news.json", "w", encoding="utf-8") as f:
        json.dump(all_posts, f, ensure_ascii=False, indent=2)

    print(f"\n✅ {len(all_posts)} political news posts saved in political_news.json")
    return all_posts


if __name__ == "__main__":
    token = load_token()
    if token:
        fetch_political_news(token, query="politics OR politique OR news", max_posts=100)
# Out:
# [2025-07-03T18:51:16.634Z] @tiina-liisa.bsky.social: There are probably more.
#
# ✅ 1 political news posts saved in political_news.json

# %% [markdown]
# TEST 3 :  FOnctionne bien

# %%
def fetch_newsfeed(access_token, limit=50, max_posts=200):
    """
    Fetch your authenticated Bluesky newsfeed (timeline).
    """
    url = "https://bsky.social/xrpc/app.bsky.feed.getPosts"
    headers = {"Authorization": f"Bearer {access_token}"}

    all_posts = []
    cursor = None

    while len(all_posts) < max_posts:
        params = {"limit": limit}
        if cursor:
            params["cursor"] = cursor

        r = requests.get(url, headers=headers, params=params, timeout=10)
        if r.status_code != 200:
            print("❌ Error:", r.status_code, r.text)
            break

        data = r.json()
        feed = data.get("feed", [])
        if not feed:
            print("No more posts found.")
            break

        for item in feed:
            post = item.get("post", {})
            record = post.get("record", {})
            author = post.get("author", {}).get("handle", "unknown")
            text = record.get("text", "")
            created = record.get("createdAt", "")
            print(f"[{created}] @{author}: {text[:100]}")
            all_posts.append(post)

            if len(all_posts) >= max_posts:
                break

        cursor = data.get("cursor")
        if not cursor:
            break

        time.sleep(1)

    with open("newsfeed_posts.json", "w", encoding="utf-8") as f:
        json.dump(all_posts, f, ensure_ascii=False, indent=2)

    print(f"\n✅ {len(all_posts)} posts saved in newsfeed_posts.json")
    return all_posts


if __name__ == "__main__":
    token = load_token()
    if token:
        fetch_newsfeed(token, max_posts=100)
# Out:
# ❌ Error: 400 {"error":"InvalidRequest","message":"Error: Params must have the property \"uris\""}
#
# ✅ 0 posts saved in newsfeed_posts.json

# %% [markdown]
# TEST 4 :  FOnctionne bien

# %%
def get_news_posts(access_jwt, query="news", limit=25, cursor=None):
    """
    Récupère les posts publics de Bluesky correspondant à une recherche donnée.
    
    Args:
        access_jwt (str): Jeton d'accès (accessJwt) obtenu après login.
        query (str): Terme de recherche (ex: 'politics', 'news', 'international').
        limit (int): Nombre maximum de posts par requête.
        cursor (str): Curseur pour paginer les résultats.

    Returns:
        dict: Résultats de l'appel API Bluesky.
    """
    url = "https://bsky.social/xrpc/app.bsky.feed.searchPosts"

    headers = {
        "Authorization": f"Bearer {access_jwt}",
    }

    params = {
        "q": query,     # mot-clé de recherche
        "limit": limit, # nombre de posts à récupérer
    }

    if cursor:
        params["cursor"] = cursor

    response = requests.get(url, headers=headers, params=params)

    if response.status_code == 200:
        return response.json()
    else:
        print(f"❌ Erreur {response.status_code}: {response.text}")
        return None


if __name__ == "__main__":
    # 1️⃣ Charger ton access token depuis le fichier token.json (créé lors du login)
    with open("token.json", "r", encoding="utf-8") as f:
        token_data = json.load(f)
        access_jwt = token_data["accessJwt"]

    # 2️⃣ Appeler la fonction
    data = get_news_posts(access_jwt, query="news", limit=100)

    if data:
        posts = data.get("posts", [])
        print(f"✅ {len(posts)} posts récupérés sur le thème 'news'.\n")

        # 3️⃣ Afficher un aperçu simple
        for p in posts[:5]:  # affiche les 5 premiers
            author = p.get("author", {}).get("handle", "inconnu")
            text = p.get("record", {}).get("text", "")
            print(f"👤 {author}\n🗞️ {text}\n{'-'*60}")
# Out:
# ✅ 100 posts récupérés sur le thème 'news'.
#
# 👤 richardtuffin.bsky.social
# 🗞️ Nice to kick back and actually enjoy watching the news - for the first time in a very long time!
# ------------------------------------------------------------
# 👤 share-market.bsky.social
# 🗞️ 🎬 TCS share latest news / हो सकती है बड़ी गिरावट / जानिए गिरावट के बड़े कारण
# ---
# https://www.youtube.com/watch?v=g5vvclIUo68
# ------------------------------------------------------------
# 👤 adamcobb.bsky.social
# 🗞️ Also, it was item three or four on Breakfast, which was nice. That's about where 'New York has a new mayor' should be on a British news programme.
# ------------------------------------------------------------
# 👤 sgtspike.bsky.social
# 🗞️ 🌵So happy it was a night of Republican losers across the country!!
# #Tucson
# www.kvoa.com/news/decisio...
# ------------------------------------------------------------
# 👤 zgq.bsky.social
# 🗞️ Democratic justices keep seats on Pennsylvania high court - POLITICO https://www.politico.com/news/2025/11/04/democrats-win-pennsylvania-supreme-court-00633675
# ------------------------------------------------------------

# %% [markdown]
# TEST IMPORT TO MONGO

# %%
# import_json_to_mongo.py
import json
from pymongo import MongoClient
import os
from mongo_connection import connect_to_mongo

# Accès MongoDB
MONGO_URI = os.getenv("MONGO_URI")

# Le nom de la database
DB_NAME = "projet_bluesky"

# Nommer le nom de la collection qui apparaitra dans MongoDB
COLLECTION_NAME = "newsfeed"

# Récupère le fichier json contenant les posts
JSON_FILE = "political_posts.json" 


# Fonction qui permet d'importer les posts en json sur mongoDB.
def import_json_to_mongo(json_path, db, collection_name):
    """Importer un fichier JSON dans une collection MongoDB."""
    with open(json_path, "r", encoding="utf-8") as f:
        data = json.load(f)

    if isinstance(data, dict):

        data = [data]

    collection = db[collection_name]

    if not data:
        print("⚠️ Aucun document à insérer.")
        return

    # Éviter les doublons simples (par texte et auteur)
    inserted_count = 0
    for doc in data:
        if not collection.find_one({"text": doc.get("text"), "author": doc.get("author")}):
            collection.insert_one(doc)
            inserted_count += 1

    print(f"✅ {inserted_count} nouveaux posts insérés dans la collection '{collection_name}'.")

if __name__ == "__main__":
    try:
        db = connect_to_mongo()
        import_json_to_mongo(JSON_FILE, db, COLLECTION_NAME)
    except Exception as e:
        print("❌ Erreur :", e)

# %% [markdown]
# TEST CONNEXION BLUESKY et TOKEN (NEW and REFRESH)

# %%
import os
import requests
from dotenv import load_dotenv

# Load credentials from .env
load_dotenv()

# Bluesky API endpoints
LOGIN_URL = "https://bsky.social/xrpc/com.atproto.server.createSession"
REFRESH_URL = "https://bsky.social/xrpc/com.atproto.server.refreshSession"



def connect_to_bluesky( timeout: int = 10):
    """
    Connects to Bluesky and returns tokens (accessJwt, refreshJwt) in memory.

    """

    identifier = os.getenv("BSKY_IDENTIFIER")
    password = os.getenv("BSKY_PASSWORD")

    if not identifier or not password:
        raise ValueError("❌ Missing BSKY_IDENTIFIER or BSKY_PASSWORD in .env file.")

    try:
        response = requests.post(LOGIN_URL, json={"identifier": identifier, "password": password}, timeout=timeout)
        response.raise_for_status()

        data = response.json()
        access = data.get("accessJwt")
        refresh = data.get("refreshJwt")

        if not access or not refresh:
            raise ValueError("❌ Login failed — missing tokens.")

        print("✅ Successfully connected to Bluesky.")
        return {"accessJwt": access, "refreshJwt": refresh}

    except requests.exceptions.Timeout:
        print("⏰ Connection timed out.")
    except requests.exceptions.ConnectionError:
        print("🌐 Network connection failed.")
    except requests.exceptions.HTTPError as e:
        print(f"❌ HTTP error: {e.response.status_code} - {e.response.text}")
    except Exception as e:
        print(f"⚠️ Unexpected error: {e}")

    return None


def refresh_access_token( timeout: int = 10):
    """
    Uses a valid refresh token to obtain a new accessJwt and refreshJwt.
    Returns new tokens if successful.
    """
    refresh_token = 'insert how to get the refresh tokens'

    headers = {"Authorization": f"Bearer {refresh_token}"}



    try:
        response = requests.post(REFRESH_URL, headers=headers, timeout=timeout)
        response.raise_for_status()

        data = response.json()
        access = data.get("accessJwt")
        new_refresh = data.get("refreshJwt")

        if not access:
            raise ValueError("❌ Token refresh failed — no accessJwt returned.")

        print("🔄 Access token successfully refreshed.")
        return {"accessJwt": access, "refreshJwt": new_refresh or refresh_token}

    except requests.exceptions.Timeout:
        print("⏰ Refresh request timed out.")
    except requests.exceptions.ConnectionError:
        print("🌐 Network error during refresh.")
    except requests.exceptions.HTTPError as e:
        print(f"❌ HTTP error during refresh: {e.response.status_code} - {e.response.text}")
    except Exception as e:
        print(f"⚠️ Unexpected error during refresh: {e}")

    return None


# Test script
if __name__ == "__main__":
    tokens = connect_to_bluesky()
    if tokens:
        print("\n🔑 Tokens received:")
        print({
            "accessJwt": tokens["accessJwt"][:50] + "...",
            "refreshJwt": tokens["refreshJwt"][:50] + "..."
        })

        # Simulate refreshing the token
        refreshed = refresh_access_token(tokens["refreshJwt"])
        if refreshed:
            print("\n♻️ New tokens after refresh:")
            print({
                "accessJwt": refreshed["accessJwt"][:50] + "...",
                "refreshJwt": refreshed["refreshJwt"][:50] + "..."
            })
# Out:
# ✅ Successfully connected to Bluesky.
#
# 🔑 Tokens received:
# {'accessJwt': 'eyJ0eXAiOiJhdCtqd3QiLCJhbGciOiJFUzI1NksifQ.eyJzY29...', 'refreshJwt': 'eyJ0eXAiOiJyZWZyZXNoK2p3dCIsImFsZyI6IkVTMjU2SyJ9.e...'}
# ⚠️ Unexpected error during refresh: Timeout value connect was eyJ0eXAiOiJyZWZyZXNoK2p3dCIsImFsZyI6IkVTMjU2SyJ9.eyJzY29wZSI6ImNvbS5hdHByb3RvLnJlZnJlc2giLCJzdWIiOiJkaWQ6cGxjOmx4cXNsejN6NzUzdGlzaGxkaW9hYnRyYiIsImF1ZCI6ImRpZDp3ZWI6YnNreS5zb2NpYWwiLCJqdGkiOiJrUys4ejNCRHRvQXF4aDQwaTQva21hamNDSU1QSUVRbERhQ3JYa3lqUGdBIiwiaWF0IjoxNzYyNDIxNTQwLCJleHAiOjE3NzAxOTc1NDB9.fkX0ymjVtnuOM5NBunpjk1jYzcYnwgYiHMNvad-V0f_kffOK0RdukTEZtTPxjH_x7qYrGBkY-HyztkzutwaHhA, but it must be an int, float or None.
